# %%
#! /usr/bin/python3

from __future__ import print_function, division

from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, Multiply, concatenate, Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization, Activation, Embedding, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import relu, tanh, linear
from tensorflow import keras
from tensorflow.keras.utils import Progbar
import tensorflow as tf

from collections import defaultdict
import pickle as pickle
from PIL import Image

import matplotlib.pyplot as plt

import numpy as np

IMG_SIZE = 128

# %%
np.random.seed(1337)

class ACGAN():
    def __init__(self):

        self.img_rows = IMG_SIZE
        self.img_cols = IMG_SIZE
        self.channels = 3
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        self.num_classes = 2
        self.latent_dim = 20000

        optimizer = Adam(0.0002, 0.5)
        losses = ['binary_crossentropy', 'sparse_categorical_crossentropy']

        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss=losses,optimizer=optimizer,metrics=['accuracy'])

        self.generator = self.build_generator()

        noise = Input(shape=(self.latent_dim,))
        label = Input(shape=(1,))
        img = self.generator([label,noise])

        self.discriminator.trainable = False

        valid, target_label = self.discriminator(img)

        self.combined = Model([label,noise], [valid, target_label])
        self.combined.compile(loss=losses,optimizer=optimizer)

    def build_generator(self):

        noise = Input(shape=(self.latent_dim,))
        label = Input(shape=(1,), dtype='int32')

        noise_branch = Dense(1024*8*8)(noise)
        noise_branch = relu(noise_branch)
        noise_branch = Reshape((8, 8, 1024))(noise_branch)
        noise_branch = Model(inputs=noise, outputs=noise_branch)

        label_branch = Embedding(input_dim=50,output_dim=1)(label)
        label_branch = Dense(64,input_shape=(8,8))(label_branch)
        label_branch = linear(label_branch)
        label_branch = Reshape((8, 8, 1),)(label_branch)
        label_branch = Model(inputs=label, outputs=label_branch)

        combined = concatenate([noise_branch.output, label_branch.output])

        combined = Conv2DTranspose(512, (5,5), strides=(2,2),padding="same")(combined)
        combined = BatchNormalization(momentum=0)(combined)
        combined = relu(combined)

        combined = Conv2DTranspose(256, (5,5), strides=(2,2),padding="same")(combined)
        combined = BatchNormalization(momentum=0)(combined)
        combined = relu(combined)

        combined = Conv2DTranspose(128, (5,5), strides=(2,2),padding="same")(combined)
        combined = BatchNormalization(momentum=0)(combined)
        combined = relu(combined)

        combined = Conv2DTranspose(3, (5,5), strides=(2,2),padding="same")(combined)
        combined = tanh(combined)

        model = Model(inputs=[label_branch.input, noise_branch.input], outputs=combined)

        keras.utils.plot_model(model, "generator.png", show_shapes=True)

        return model

    def build_discriminator(self):

        model = Sequential()

        model.add(Conv2D(32, kernel_size=(3,3), strides=(1,1), input_shape=self.img_shape, padding="same"))
        model.add(BatchNormalization(momentum=0))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.5))

        model.add(Conv2D(64, kernel_size=(3,3), strides=(2,2), input_shape=self.img_shape, padding="same"))
        model.add(BatchNormalization(momentum=0))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.5))

        model.add(Conv2D(128, kernel_size=(3,3), strides=(2,2), padding="same"))
        model.add(BatchNormalization(momentum=0))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.5))

        model.add(Conv2D(256, kernel_size=(3,3), strides=(2,2), padding="same"))
        model.add(BatchNormalization(momentum=0))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.5))

        model.add(Conv2D(512, kernel_size=(3,3), strides=(2,2), padding="same"))
        model.add(BatchNormalization(momentum=0))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.5))

        model.add(Flatten())

        img = Input(shape=self.img_shape)

        features = model(img)

        validity = Dense(1, activation="sigmoid")(features)
        label = Dense(self.num_classes, activation="softmax")(features)

        keras.utils.plot_model(model, "discriminator.png", show_shapes=True)

        return Model(img, [validity, label])
    
    def train(self, epochs, batch_size=128):
        
        cxr_train = keras.preprocessing.image_dataset_from_directory(r"C:/ML_C/CXR8/images_gan_processed/train/",
                                                                    labels="inferred",
                                                                     batch_size=2084, image_size=(IMG_SIZE, IMG_SIZE))

        cxr_test = keras.preprocessing.image_dataset_from_directory(r"C:/ML_C/CXR8/images_gan_processed/test",
                                                                    labels="inferred",
                                                                    batch_size=1800, image_size=(IMG_SIZE,IMG_SIZE))

        cxr_train_images = []
        cxr_train_labels = []
        cxr_test_images = []
        cxr_test_labels = []

        for images, labels in cxr_train:
            for i in range(len(images)):
              cxr_train_images.append(images[i])
              cxr_train_labels.append(labels[i])

        for images, labels in cxr_test:
            for i in range(len(images)):
              cxr_test_images.append(images[i])
              cxr_test_labels.append(labels[i])

        cxr_train_images = np.array(cxr_train_images)
        cxr_train_labels = np.array(cxr_train_labels)
        cxr_test_images = np.array(cxr_test_images)
        cxr_test_labels = np.array(cxr_test_labels)

        X_train = (cxr_train_images.astype(np.float32) - 127.5) / 127.5

        X_test = (cxr_test_images.astype(np.float32) - 127.5) / 127.5

        nb_train, nb_test = X_train.shape[0], X_test.shape[0]

        train_history = defaultdict(list)
        test_history = defaultdict(list)

        y_train = cxr_train_labels
        y_test = cxr_test_labels
        for epoch in range(epochs):

            print('Epoch {} of {}'.format(epoch + 1, epochs))
            nb_batches = int(X_train.shape[0] / batch_size)
            progress_bar = Progbar(target=nb_batches)

            epoch_gen_loss = []
            epoch_disc_loss = []

            for index in range(nb_batches):
                progress_bar.update(index)

                noise = np.random.normal(0, 0.02, (batch_size, self.latent_dim))

                image_batch = X_train[index * batch_size:(index + 1) * batch_size]
                label_batch = y_train[index * batch_size:(index + 1) * batch_size]

                sampled_labels = np.random.randint(0, 1, batch_size)

                generated_images = self.generator.predict([sampled_labels.reshape((-1, 1)),noise], verbose=0)

                X = np.concatenate((image_batch, generated_images))
                y = np.array([1] * batch_size + [0] * batch_size)

                aux_y = np.concatenate((label_batch, sampled_labels))

                epoch_disc_loss.append(self.discriminator.train_on_batch(X, [y, aux_y]))

                noise = np.random.normal(0, 0.02, (2 * batch_size, self.latent_dim))
                sampled_labels = np.random.randint(0, 1, 2 * batch_size)

                trick = np.ones(2 * batch_size)

                epoch_gen_loss.append(self.combined.train_on_batch([sampled_labels.reshape((-1, 1)), noise], [trick, sampled_labels]))

            print('\nTesting for epoch {}:'.format(epoch + 1))
            noise = np.random.normal(0, 0.02, (nb_test, self.latent_dim))

            sampled_labels = np.random.randint(0, 1, nb_test)
            generated_images = self.generator.predict([sampled_labels.reshape((-1, 1)), noise], verbose=False)

            X = np.concatenate((X_test, generated_images))
            y = np.array([1] * nb_test + [0] * nb_test)
            aux_y = np.concatenate((y_test, sampled_labels), axis=0)

            discriminator_test_loss = self.discriminator.evaluate(X, [y, aux_y], verbose=False)

            discriminator_train_loss = np.mean(np.array(epoch_disc_loss), axis=0)

            noise = np.random.normal(0, 0.02, (2 * nb_test, self.latent_dim))
            sampled_labels = np.random.randint(0, 1, 2 * nb_test)

            trick = np.ones(2 * nb_test)

            generator_test_loss = self.combined.evaluate([sampled_labels.reshape((-1, 1)),noise],[trick, sampled_labels], verbose=False)

            generator_train_loss = np.mean(np.array(epoch_gen_loss), axis=0)

            train_history['generator'].append(generator_train_loss)
            train_history['discriminator'].append(discriminator_train_loss)

            test_history['generator'].append(generator_test_loss)
            test_history['discriminator'].append(discriminator_test_loss)

            print('{0:<22s} | {1:4s} | {2:15s} | {3:5s}'.format('component', *self.discriminator.metrics_names))
            print('-' * 65)

            ROW_FMT = '{0:<22s} | {1:<4.2f} | {2:<15.2f} | {3:<5.2f}'
            print(ROW_FMT.format('generator (train)',*train_history['generator'][-1]))
            print(ROW_FMT.format('generator (test)',*test_history['generator'][-1]))
            print(ROW_FMT.format('discriminator (train)',*train_history['discriminator'][-1]))
            print(ROW_FMT.format('discriminator (test)',*test_history['discriminator'][-1]))

            if epoch % 100 == 0:
                self.generator.save('saved_model/generator_epoch_{0:03d}.hdf5'.format(epoch))

            r, c = 2, 2
            noise = np.random.normal(0, 0.02, (r * c, self.latent_dim))

            sampled_labels = np.array([num for _ in range(r) for num in range(c)])
            gen_imgs = self.generator.predict([sampled_labels, noise])
            gen_imgs = 0.5 * gen_imgs + 0.5

            fig, axs = plt.subplots(r, c)
            cnt = 0
            for i in range(r):
                for j in range(c):
                    axs[i,j].imshow(gen_imgs[cnt,:,:,0], cmap='gray')
                    axs[i,j].axis('off')
                    cnt += 1
            fig.savefig("GAN_images/%d.png" % epoch)
            plt.close()

        pickle.dump({'train': train_history, 'test': test_history},open('acgan-history.pkl', 'wb'))

# %%
if __name__ == '__main__':
        acgan = ACGAN()
        acgan.train(epochs=2200, batch_size=16)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
# Found 4394 files belonging to 2 classes.
# Found 26 files belonging to 2 classes.
# Epoch 1 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 1:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 4.04 | 3.92            | 0.12
# generator (test)       | 0.24 | 0.00            | 0.24
# discriminator (train)  | 1.33 | 0.55            | 0.78
# discriminator (test)   | 3.86 | 3.37            | 0.49
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 2 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 2:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 3.61 | 3.48            | 0.13
# generator (test)       | 0.03 | 0.01            | 0.02
# discriminator (train)  | 1.60 | 0.74            | 0.86
# discriminator (test)   | 3.16 | 2.40            | 0.76
# Epoch 3 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 3:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.41 | 2.23            | 0.18
# generator (test)       | 2.40 | 2.40            | 0.00
# discriminator (train)  | 1.62 | 0.77            | 0.85
# discriminator (test)   | 0.68 | 0.15            | 0.53
# Epoch 4 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 4:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.24 | 2.06            | 0.18
# generator (test)       | 1.72 | 1.71            | 0.01
# discriminator (train)  | 1.48 | 0.67            | 0.81
# discriminator (test)   | 0.73 | 0.25            | 0.48
# Epoch 5 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 5:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.29 | 2.11            | 0.17
# generator (test)       | 2.61 | 2.60            | 0.01
# discriminator (train)  | 1.52 | 0.71            | 0.81
# discriminator (test)   | 0.58 | 0.15            | 0.43
# Epoch 6 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 6:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.42 | 2.26            | 0.16
# generator (test)       | 2.87 | 2.87            | 0.00
# discriminator (train)  | 1.40 | 0.63            | 0.77
# discriminator (test)   | 0.76 | 0.12            | 0.65
# Epoch 7 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 7:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.45 | 2.30            | 0.14
# generator (test)       | 1.11 | 1.07            | 0.04
# discriminator (train)  | 1.30 | 0.54            | 0.76
# discriminator (test)   | 0.86 | 0.40            | 0.46
# Epoch 8 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 8:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.61 | 2.46            | 0.15
# generator (test)       | 0.70 | 0.62            | 0.08
# discriminator (train)  | 1.30 | 0.59            | 0.71
# discriminator (test)   | 0.96 | 0.56            | 0.40
# Epoch 9 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 9:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.53 | 2.39            | 0.14
# generator (test)       | 1.55 | 1.53            | 0.01
# discriminator (train)  | 1.27 | 0.57            | 0.70
# discriminator (test)   | 0.74 | 0.24            | 0.50
# Epoch 10 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 10:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.37 | 2.23            | 0.15
# generator (test)       | 2.83 | 2.82            | 0.01
# discriminator (train)  | 1.30 | 0.59            | 0.71
# discriminator (test)   | 1.22 | 0.39            | 0.83
# Epoch 11 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 11:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.30 | 2.16            | 0.14
# generator (test)       | 4.77 | 4.76            | 0.01
# discriminator (train)  | 1.23 | 0.54            | 0.69
# discriminator (test)   | 0.67 | 0.09            | 0.58
# Epoch 12 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 12:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.74 | 2.60            | 0.13
# generator (test)       | 3.90 | 3.90            | 0.00
# discriminator (train)  | 1.20 | 0.52            | 0.69
# discriminator (test)   | 0.49 | 0.02            | 0.47
# Epoch 13 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 13:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.43 | 2.29            | 0.13
# generator (test)       | 2.05 | 2.04            | 0.01
# discriminator (train)  | 1.25 | 0.56            | 0.69
# discriminator (test)   | 0.50 | 0.15            | 0.36
# Epoch 14 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 14:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.51 | 2.38            | 0.13
# generator (test)       | 2.14 | 2.13            | 0.01
# discriminator (train)  | 1.23 | 0.55            | 0.68
# discriminator (test)   | 0.48 | 0.08            | 0.40
# Epoch 15 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 15:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.44 | 2.31            | 0.13
# generator (test)       | 2.01 | 1.99            | 0.02
# discriminator (train)  | 1.21 | 0.54            | 0.67
# discriminator (test)   | 0.48 | 0.10            | 0.38
# Epoch 16 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 16:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.46 | 2.33            | 0.13
# generator (test)       | 1.91 | 1.88            | 0.03
# discriminator (train)  | 1.21 | 0.54            | 0.66
# discriminator (test)   | 0.63 | 0.22            | 0.41
# Epoch 17 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 17:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.36 | 2.22            | 0.13
# generator (test)       | 3.38 | 3.36            | 0.02
# discriminator (train)  | 1.20 | 0.53            | 0.67
# discriminator (test)   | 0.78 | 0.29            | 0.50
# Epoch 18 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 18:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.39 | 2.26            | 0.13
# generator (test)       | 1.53 | 1.47            | 0.05
# discriminator (train)  | 1.18 | 0.52            | 0.66
# discriminator (test)   | 0.64 | 0.26            | 0.38
# Epoch 19 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 19:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.56 | 2.45            | 0.11
# generator (test)       | 1.11 | 1.03            | 0.07
# discriminator (train)  | 1.17 | 0.54            | 0.63
# discriminator (test)   | 0.71 | 0.30            | 0.41
# Epoch 20 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 20:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.48 | 2.36            | 0.12
# generator (test)       | 3.48 | 3.47            | 0.01
# discriminator (train)  | 1.15 | 0.50            | 0.65
# discriminator (test)   | 1.12 | 0.47            | 0.64
# Epoch 21 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 21:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.54 | 2.41            | 0.13
# generator (test)       | 4.34 | 4.33            | 0.01
# discriminator (train)  | 1.12 | 0.48            | 0.64
# discriminator (test)   | 1.19 | 0.69            | 0.50
# Epoch 22 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 22:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.50 | 2.38            | 0.12
# generator (test)       | 2.38 | 2.33            | 0.05
# discriminator (train)  | 1.15 | 0.50            | 0.64
# discriminator (test)   | 0.64 | 0.24            | 0.39
# Epoch 23 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 23:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.48 | 2.36            | 0.13
# generator (test)       | 3.95 | 3.94            | 0.01
# discriminator (train)  | 1.15 | 0.51            | 0.65
# discriminator (test)   | 0.86 | 0.37            | 0.49
# Epoch 24 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 24:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.49 | 2.36            | 0.13
# generator (test)       | 3.50 | 3.48            | 0.02
# discriminator (train)  | 1.13 | 0.50            | 0.63
# discriminator (test)   | 0.90 | 0.35            | 0.55
# Epoch 25 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 25:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.53 | 2.41            | 0.13
# generator (test)       | 4.36 | 4.35            | 0.01
# discriminator (train)  | 1.10 | 0.48            | 0.62
# discriminator (test)   | 0.53 | 0.12            | 0.41
# Epoch 26 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 26:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.52 | 2.40            | 0.12
# generator (test)       | 3.11 | 3.09            | 0.01
# discriminator (train)  | 1.10 | 0.48            | 0.62
# discriminator (test)   | 1.01 | 0.53            | 0.47
# Epoch 27 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 27:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.49 | 2.38            | 0.12
# generator (test)       | 2.37 | 2.34            | 0.04
# discriminator (train)  | 1.10 | 0.48            | 0.62
# discriminator (test)   | 1.39 | 0.93            | 0.46
# Epoch 28 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 28:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.53 | 2.42            | 0.12
# generator (test)       | 5.76 | 5.75            | 0.01
# discriminator (train)  | 1.10 | 0.47            | 0.63
# discriminator (test)   | 0.83 | 0.36            | 0.47
# Epoch 29 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 29:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.45 | 2.32            | 0.13
# generator (test)       | 2.19 | 2.16            | 0.02
# discriminator (train)  | 1.07 | 0.45            | 0.62
# discriminator (test)   | 1.48 | 0.87            | 0.61
# Epoch 30 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 30:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.51 | 2.39            | 0.12
# generator (test)       | 2.10 | 2.08            | 0.02
# discriminator (train)  | 1.07 | 0.45            | 0.61
# discriminator (test)   | 1.34 | 0.62            | 0.71
# Epoch 31 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 31:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.45 | 2.33            | 0.12
# generator (test)       | 2.10 | 2.06            | 0.04
# discriminator (train)  | 1.11 | 0.49            | 0.62
# discriminator (test)   | 0.97 | 0.46            | 0.51
# Epoch 32 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 32:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.43 | 2.31            | 0.12
# generator (test)       | 3.84 | 3.80            | 0.03
# discriminator (train)  | 1.13 | 0.51            | 0.62
# discriminator (test)   | 0.75 | 0.37            | 0.38
# Epoch 33 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 33:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.32 | 2.19            | 0.13
# generator (test)       | 3.42 | 3.39            | 0.03
# discriminator (train)  | 1.12 | 0.51            | 0.61
# discriminator (test)   | 0.69 | 0.21            | 0.48
# Epoch 34 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 34:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.28 | 2.15            | 0.13
# generator (test)       | 2.19 | 2.13            | 0.06
# discriminator (train)  | 1.13 | 0.52            | 0.61
# discriminator (test)   | 0.93 | 0.43            | 0.50
# Epoch 35 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 35:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.18 | 2.04            | 0.14
# generator (test)       | 2.10 | 2.07            | 0.03
# discriminator (train)  | 1.13 | 0.52            | 0.61
# discriminator (test)   | 0.83 | 0.35            | 0.48
# Epoch 36 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 36:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.51 | 2.40            | 0.12
# generator (test)       | 2.94 | 2.91            | 0.04
# discriminator (train)  | 1.05 | 0.45            | 0.59
# discriminator (test)   | 1.41 | 0.89            | 0.52
# Epoch 37 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 37:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.31 | 2.19            | 0.13
# generator (test)       | 2.37 | 2.34            | 0.03
# discriminator (train)  | 1.07 | 0.47            | 0.60
# discriminator (test)   | 0.55 | 0.17            | 0.38
# Epoch 38 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 38:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.41 | 2.29            | 0.12
# generator (test)       | 2.19 | 2.12            | 0.07
# discriminator (train)  | 1.05 | 0.45            | 0.60
# discriminator (test)   | 0.82 | 0.42            | 0.41
# Epoch 39 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 39:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.32 | 2.19            | 0.13
# generator (test)       | 1.73 | 1.68            | 0.05
# discriminator (train)  | 1.09 | 0.49            | 0.60
# discriminator (test)   | 0.64 | 0.23            | 0.41
# Epoch 40 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 40:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.43 | 2.30            | 0.12
# generator (test)       | 3.89 | 3.86            | 0.03
# discriminator (train)  | 1.05 | 0.46            | 0.59
# discriminator (test)   | 0.58 | 0.18            | 0.40
# Epoch 41 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 41:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.38 | 2.26            | 0.12
# generator (test)       | 2.10 | 2.05            | 0.05
# discriminator (train)  | 1.04 | 0.44            | 0.60
# discriminator (test)   | 0.55 | 0.15            | 0.40
# Epoch 42 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 42:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.49 | 2.37            | 0.12
# generator (test)       | 2.68 | 2.63            | 0.05
# discriminator (train)  | 1.01 | 0.43            | 0.58
# discriminator (test)   | 0.89 | 0.43            | 0.46
# Epoch 43 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 43:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.53 | 2.42            | 0.11
# generator (test)       | 1.84 | 1.78            | 0.06
# discriminator (train)  | 1.00 | 0.42            | 0.58
# discriminator (test)   | 0.59 | 0.20            | 0.39
# Epoch 44 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 44:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.60 | 2.49            | 0.11
# generator (test)       | 1.77 | 1.69            | 0.08
# discriminator (train)  | 0.98 | 0.40            | 0.57
# discriminator (test)   | 0.75 | 0.32            | 0.43
# Epoch 45 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 45:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.58 | 2.48            | 0.11
# generator (test)       | 2.40 | 2.36            | 0.04
# discriminator (train)  | 0.99 | 0.41            | 0.58
# discriminator (test)   | 1.01 | 0.60            | 0.41
# Epoch 46 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 46:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.50 | 2.39            | 0.11
# generator (test)       | 3.16 | 3.13            | 0.03
# discriminator (train)  | 1.00 | 0.41            | 0.59
# discriminator (test)   | 0.77 | 0.28            | 0.49
# Epoch 47 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 47:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.71 | 2.61            | 0.10
# generator (test)       | 2.75 | 2.72            | 0.03
# discriminator (train)  | 0.93 | 0.38            | 0.56
# discriminator (test)   | 0.65 | 0.26            | 0.39
# Epoch 48 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 48:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.59 | 2.48            | 0.11
# generator (test)       | 2.82 | 2.79            | 0.04
# discriminator (train)  | 0.96 | 0.39            | 0.57
# discriminator (test)   | 1.09 | 0.64            | 0.45
# Epoch 49 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 49:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.64 | 2.53            | 0.10
# generator (test)       | 2.67 | 2.51            | 0.16
# discriminator (train)  | 0.94 | 0.37            | 0.57
# discriminator (test)   | 0.72 | 0.28            | 0.44
# Epoch 50 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 50:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.62 | 2.52            | 0.10
# generator (test)       | 1.91 | 1.79            | 0.13
# discriminator (train)  | 0.95 | 0.38            | 0.57
# discriminator (test)   | 0.61 | 0.20            | 0.42
# Epoch 51 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 51:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.67 | 2.56            | 0.11
# generator (test)       | 1.85 | 1.74            | 0.11
# discriminator (train)  | 0.97 | 0.40            | 0.57
# discriminator (test)   | 1.21 | 0.72            | 0.49
# Epoch 52 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 52:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.37 | 2.25            | 0.13
# generator (test)       | 3.91 | 3.86            | 0.05
# discriminator (train)  | 1.03 | 0.46            | 0.57
# discriminator (test)   | 0.70 | 0.26            | 0.44
# Epoch 53 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 53:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.30 | 2.17            | 0.12
# generator (test)       | 2.24 | 2.14            | 0.10
# discriminator (train)  | 1.03 | 0.45            | 0.58
# discriminator (test)   | 1.06 | 0.61            | 0.45
# Epoch 54 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 54:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.53 | 2.42            | 0.11
# generator (test)       | 1.83 | 1.70            | 0.14
# discriminator (train)  | 0.98 | 0.42            | 0.57
# discriminator (test)   | 0.66 | 0.23            | 0.43
# Epoch 55 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 55:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.41 | 2.29            | 0.12
# generator (test)       | 2.22 | 2.14            | 0.08
# discriminator (train)  | 0.98 | 0.41            | 0.57
# discriminator (test)   | 0.57 | 0.14            | 0.42
# Epoch 56 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 56:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.40 | 2.28            | 0.12
# generator (test)       | 2.01 | 1.94            | 0.07
# discriminator (train)  | 0.98 | 0.43            | 0.56
# discriminator (test)   | 0.54 | 0.13            | 0.41
# Epoch 57 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 57:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.38 | 2.26            | 0.12
# generator (test)       | 2.67 | 2.53            | 0.14
# discriminator (train)  | 0.98 | 0.42            | 0.56
# discriminator (test)   | 0.70 | 0.24            | 0.45
# Epoch 58 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 58:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.48 | 2.37            | 0.12
# generator (test)       | 1.55 | 1.41            | 0.14
# discriminator (train)  | 0.97 | 0.40            | 0.56
# discriminator (test)   | 0.72 | 0.29            | 0.43
# Epoch 59 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 59:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.27 | 2.15            | 0.13
# generator (test)       | 2.09 | 1.99            | 0.10
# discriminator (train)  | 1.03 | 0.46            | 0.57
# discriminator (test)   | 0.56 | 0.12            | 0.44
# Epoch 60 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 60:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.05 | 1.92            | 0.14
# generator (test)       | 1.43 | 1.25            | 0.18
# discriminator (train)  | 1.06 | 0.48            | 0.58
# discriminator (test)   | 0.89 | 0.45            | 0.44
# Epoch 61 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 61:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.02 | 1.87            | 0.15
# generator (test)       | 1.95 | 1.79            | 0.16
# discriminator (train)  | 1.06 | 0.48            | 0.58
# discriminator (test)   | 0.63 | 0.20            | 0.43
# Epoch 62 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 62:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.80 | 1.63            | 0.16
# generator (test)       | 1.49 | 1.33            | 0.16
# discriminator (train)  | 1.11 | 0.53            | 0.58
# discriminator (test)   | 0.78 | 0.34            | 0.44
# Epoch 63 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 63:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.70 | 1.53            | 0.17
# generator (test)       | 1.36 | 1.16            | 0.20
# discriminator (train)  | 1.12 | 0.54            | 0.58
# discriminator (test)   | 0.72 | 0.27            | 0.45
# Epoch 64 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 64:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.74 | 1.57            | 0.17
# generator (test)       | 1.31 | 1.08            | 0.23
# discriminator (train)  | 1.11 | 0.53            | 0.58
# discriminator (test)   | 0.68 | 0.23            | 0.45
# Epoch 65 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 65:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.64 | 1.45            | 0.18
# generator (test)       | 1.95 | 1.78            | 0.17
# discriminator (train)  | 1.13 | 0.55            | 0.58
# discriminator (test)   | 0.59 | 0.12            | 0.47
# Epoch 66 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 66:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.68 | 1.51            | 0.18
# generator (test)       | 1.83 | 1.67            | 0.16
# discriminator (train)  | 1.13 | 0.54            | 0.58
# discriminator (test)   | 0.79 | 0.32            | 0.47
# Epoch 67 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 67:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.58 | 1.40            | 0.18
# generator (test)       | 2.04 | 1.90            | 0.14
# discriminator (train)  | 1.14 | 0.56            | 0.58
# discriminator (test)   | 0.62 | 0.20            | 0.42
# Epoch 68 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 68:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.63 | 1.45            | 0.18
# generator (test)       | 1.40 | 1.27            | 0.13
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.64 | 0.22            | 0.42
# Epoch 69 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 69:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.58 | 1.40            | 0.18
# generator (test)       | 1.59 | 1.45            | 0.14
# discriminator (train)  | 1.14 | 0.56            | 0.58
# discriminator (test)   | 0.64 | 0.22            | 0.42
# Epoch 70 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 70:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.57 | 1.38            | 0.19
# generator (test)       | 1.61 | 1.45            | 0.16
# discriminator (train)  | 1.15 | 0.57            | 0.59
# discriminator (test)   | 0.67 | 0.22            | 0.45
# Epoch 71 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 71:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.56 | 1.38            | 0.19
# generator (test)       | 1.88 | 1.75            | 0.13
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.61 | 0.20            | 0.41
# Epoch 72 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 72:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.57 | 1.39            | 0.18
# generator (test)       | 1.42 | 1.21            | 0.21
# discriminator (train)  | 1.14 | 0.56            | 0.58
# discriminator (test)   | 0.72 | 0.26            | 0.46
# Epoch 73 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 73:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.51 | 1.33            | 0.18
# generator (test)       | 1.53 | 1.36            | 0.17
# discriminator (train)  | 1.14 | 0.57            | 0.57
# discriminator (test)   | 0.68 | 0.26            | 0.42
# Epoch 74 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 74:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.52 | 1.33            | 0.19
# generator (test)       | 1.51 | 1.39            | 0.13
# discriminator (train)  | 1.14 | 0.56            | 0.58
# discriminator (test)   | 0.62 | 0.21            | 0.41
# Epoch 75 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 75:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.59 | 1.40            | 0.18
# generator (test)       | 1.52 | 1.34            | 0.19
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.68 | 0.20            | 0.47
# Epoch 76 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 76:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.49 | 1.30            | 0.19
# generator (test)       | 1.90 | 1.77            | 0.14
# discriminator (train)  | 1.14 | 0.56            | 0.58
# discriminator (test)   | 0.59 | 0.18            | 0.42
# Epoch 77 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 77:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.49 | 1.30            | 0.19
# generator (test)       | 1.51 | 1.30            | 0.21
# discriminator (train)  | 1.15 | 0.57            | 0.58
# discriminator (test)   | 0.72 | 0.20            | 0.52
# Epoch 78 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 78:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.48 | 1.28            | 0.19
# generator (test)       | 1.71 | 1.51            | 0.20
# discriminator (train)  | 1.15 | 0.57            | 0.58
# discriminator (test)   | 0.78 | 0.33            | 0.46
# Epoch 79 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 79:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.51 | 1.32            | 0.19
# generator (test)       | 1.40 | 1.21            | 0.19
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.69 | 0.23            | 0.45
# Epoch 80 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 80:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.49 | 1.30            | 0.19
# generator (test)       | 1.72 | 1.56            | 0.16
# discriminator (train)  | 1.13 | 0.56            | 0.57
# discriminator (test)   | 0.63 | 0.20            | 0.43
# Epoch 81 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 81:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.51 | 1.32            | 0.19
# generator (test)       | 1.57 | 1.40            | 0.17
# discriminator (train)  | 1.13 | 0.56            | 0.57
# discriminator (test)   | 0.66 | 0.23            | 0.43
# Epoch 82 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 82:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.55 | 1.37            | 0.18
# generator (test)       | 2.62 | 2.53            | 0.09
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.55 | 0.15            | 0.40
# Epoch 83 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 83:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.57 | 1.39            | 0.18
# generator (test)       | 1.86 | 1.74            | 0.13
# discriminator (train)  | 1.10 | 0.54            | 0.56
# discriminator (test)   | 0.57 | 0.16            | 0.42
# Epoch 84 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 84:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.50 | 1.31            | 0.19
# generator (test)       | 1.65 | 1.48            | 0.17
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.64 | 0.19            | 0.45
# Epoch 85 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 85:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.57 | 1.39            | 0.18
# generator (test)       | 1.70 | 1.54            | 0.16
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.68 | 0.25            | 0.43
# Epoch 86 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 86:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.53 | 1.33            | 0.19
# generator (test)       | 1.55 | 1.35            | 0.20
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.71 | 0.26            | 0.45
# Epoch 87 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 87:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.58 | 1.40            | 0.19
# generator (test)       | 1.58 | 1.38            | 0.20
# discriminator (train)  | 1.10 | 0.53            | 0.57
# discriminator (test)   | 0.66 | 0.21            | 0.45
# Epoch 88 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 88:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.65 | 1.47            | 0.18
# generator (test)       | 1.57 | 1.34            | 0.22
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.73 | 0.27            | 0.47
# Epoch 89 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 89:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.69 | 1.51            | 0.18
# generator (test)       | 1.61 | 1.43            | 0.17
# discriminator (train)  | 1.10 | 0.53            | 0.57
# discriminator (test)   | 0.76 | 0.30            | 0.45
# Epoch 90 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 90:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.57 | 1.39            | 0.18
# generator (test)       | 1.29 | 1.09            | 0.20
# discriminator (train)  | 1.09 | 0.53            | 0.56
# discriminator (test)   | 0.69 | 0.22            | 0.47
# Epoch 91 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 91:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.58 | 1.40            | 0.18
# generator (test)       | 1.28 | 1.09            | 0.20
# discriminator (train)  | 1.11 | 0.54            | 0.56
# discriminator (test)   | 0.76 | 0.27            | 0.49
# Epoch 92 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 92:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.60 | 1.42            | 0.18
# generator (test)       | 1.17 | 0.93            | 0.25
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.87 | 0.37            | 0.49
# Epoch 93 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 93:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.61 | 1.42            | 0.19
# generator (test)       | 1.88 | 1.73            | 0.15
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.66 | 0.13            | 0.53
# Epoch 94 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 94:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.56 | 1.37            | 0.19
# generator (test)       | 1.27 | 1.03            | 0.24
# discriminator (train)  | 1.10 | 0.54            | 0.57
# discriminator (test)   | 0.85 | 0.29            | 0.56
# Epoch 95 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 95:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.56 | 1.37            | 0.19
# generator (test)       | 1.28 | 1.07            | 0.21
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.77 | 0.32            | 0.45
# Epoch 96 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 96:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.55 | 1.36            | 0.19
# generator (test)       | 1.62 | 1.44            | 0.18
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.71 | 0.27            | 0.44
# Epoch 97 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 97:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.58 | 1.39            | 0.18
# generator (test)       | 1.58 | 1.40            | 0.18
# discriminator (train)  | 1.10 | 0.54            | 0.57
# discriminator (test)   | 0.68 | 0.24            | 0.43
# Epoch 98 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 98:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.71 | 1.53            | 0.18
# generator (test)       | 1.55 | 1.36            | 0.19
# discriminator (train)  | 1.08 | 0.52            | 0.56
# discriminator (test)   | 0.70 | 0.19            | 0.51
# Epoch 99 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 99:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.78 | 1.60            | 0.17
# generator (test)       | 1.58 | 1.40            | 0.18
# discriminator (train)  | 1.07 | 0.51            | 0.55
# discriminator (test)   | 0.67 | 0.22            | 0.45
# Epoch 100 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 100:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.59            | 0.17
# generator (test)       | 1.87 | 1.73            | 0.15
# discriminator (train)  | 1.06 | 0.51            | 0.55
# discriminator (test)   | 0.69 | 0.14            | 0.54
# Epoch 101 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 101:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.60 | 1.41            | 0.19
# generator (test)       | 1.38 | 1.13            | 0.25
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.76 | 0.27            | 0.49
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 102 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 102:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.62 | 1.44            | 0.19
# generator (test)       | 1.80 | 1.62            | 0.18
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.67 | 0.23            | 0.44
# Epoch 103 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 103:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.55 | 1.36            | 0.19
# generator (test)       | 1.85 | 1.70            | 0.15
# discriminator (train)  | 1.12 | 0.55            | 0.57
# discriminator (test)   | 0.63 | 0.20            | 0.43
# Epoch 104 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 104:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.55 | 1.36            | 0.19
# generator (test)       | 1.55 | 1.35            | 0.21
# discriminator (train)  | 1.11 | 0.54            | 0.57
# discriminator (test)   | 0.72 | 0.26            | 0.46
# Epoch 105 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 105:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.62 | 1.43            | 0.19
# generator (test)       | 1.47 | 1.28            | 0.18
# discriminator (train)  | 1.12 | 0.56            | 0.56
# discriminator (test)   | 0.69 | 0.22            | 0.47
# Epoch 106 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 106:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.50 | 1.31            | 0.19
# generator (test)       | 1.57 | 1.41            | 0.17
# discriminator (train)  | 1.11 | 0.55            | 0.56
# discriminator (test)   | 0.66 | 0.18            | 0.48
# Epoch 107 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 107:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.59 | 1.40            | 0.19
# ...
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.77 | 1.60            | 0.17
# generator (test)       | 1.50 | 1.29            | 0.20
# discriminator (train)  | 1.00 | 0.47            | 0.54
# discriminator (test)   | 0.74 | 0.21            | 0.53
# Epoch 251 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 251:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.59            | 0.17
# generator (test)       | 1.47 | 1.25            | 0.22
# discriminator (train)  | 1.01 | 0.47            | 0.53
# discriminator (test)   | 0.74 | 0.24            | 0.49
# Epoch 252 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 252:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.74 | 1.56            | 0.18
# generator (test)       | 1.38 | 1.15            | 0.23
# discriminator (train)  | 1.04 | 0.50            | 0.54
# discriminator (test)   | 0.73 | 0.27            | 0.46
# Epoch 253 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 253:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.91 | 1.75            | 0.16
# generator (test)       | 1.44 | 1.22            | 0.22
# discriminator (train)  | 1.00 | 0.47            | 0.53
# discriminator (test)   | 0.77 | 0.27            | 0.50
# Epoch 254 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 254:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.58            | 0.18
# generator (test)       | 1.33 | 1.07            | 0.26
# discriminator (train)  | 1.04 | 0.50            | 0.54
# discriminator (test)   | 0.87 | 0.37            | 0.50
# Epoch 255 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 255:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.71 | 1.52            | 0.18
# generator (test)       | 1.51 | 1.31            | 0.20
# discriminator (train)  | 1.04 | 0.50            | 0.54
# discriminator (test)   | 0.79 | 0.30            | 0.49
# Epoch 256 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 256:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.72 | 1.54            | 0.18
# generator (test)       | 1.60 | 1.40            | 0.20
# discriminator (train)  | 1.05 | 0.51            | 0.55
# discriminator (test)   | 0.69 | 0.23            | 0.46
# Epoch 257 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 257:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.79 | 1.62            | 0.18
# generator (test)       | 1.59 | 1.43            | 0.16
# discriminator (train)  | 1.02 | 0.48            | 0.53
# discriminator (test)   | 0.67 | 0.22            | 0.45
# Epoch 258 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 258:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.82 | 1.65            | 0.17
# generator (test)       | 1.73 | 1.56            | 0.17
# discriminator (train)  | 1.01 | 0.47            | 0.53
# discriminator (test)   | 0.77 | 0.30            | 0.46
# Epoch 259 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 259:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.85 | 1.68            | 0.17
# generator (test)       | 1.78 | 1.57            | 0.21
# discriminator (train)  | 1.00 | 0.46            | 0.54
# discriminator (test)   | 0.76 | 0.24            | 0.52
# Epoch 260 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 260:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.75 | 1.57            | 0.18
# generator (test)       | 1.94 | 1.79            | 0.15
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.73 | 0.30            | 0.43
# Epoch 261 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 261:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 2.03 | 1.87            | 0.16
# generator (test)       | 1.34 | 1.15            | 0.19
# discriminator (train)  | 0.99 | 0.45            | 0.54
# discriminator (test)   | 0.75 | 0.28            | 0.47
# Epoch 262 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 262:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.58            | 0.17
# generator (test)       | 1.50 | 1.29            | 0.21
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.77 | 0.31            | 0.46
# Epoch 263 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 263:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.59            | 0.17
# generator (test)       | 1.53 | 1.36            | 0.17
# discriminator (train)  | 1.02 | 0.48            | 0.54
# discriminator (test)   | 0.64 | 0.17            | 0.47
# Epoch 264 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 264:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.82 | 1.65            | 0.17
# generator (test)       | 1.50 | 1.27            | 0.23
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.71 | 0.26            | 0.45
# Epoch 265 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 265:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.81 | 1.64            | 0.17
# generator (test)       | 1.50 | 1.32            | 0.18
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.67 | 0.21            | 0.46
# Epoch 266 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 266:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.82 | 1.65            | 0.17
# generator (test)       | 1.77 | 1.60            | 0.17
# discriminator (train)  | 1.01 | 0.48            | 0.54
# discriminator (test)   | 0.67 | 0.23            | 0.44
# Epoch 267 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 267:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.88 | 1.71            | 0.17
# generator (test)       | 1.57 | 1.33            | 0.24
# discriminator (train)  | 0.97 | 0.44            | 0.53
# discriminator (test)   | 0.72 | 0.18            | 0.54
# Epoch 268 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 268:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.87 | 1.70            | 0.17
# generator (test)       | 1.49 | 1.29            | 0.21
# discriminator (train)  | 1.02 | 0.48            | 0.53
# discriminator (test)   | 0.75 | 0.26            | 0.49
# Epoch 269 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 269:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.86 | 1.69            | 0.17
# generator (test)       | 1.54 | 1.34            | 0.20
# discriminator (train)  | 1.03 | 0.49            | 0.53
# discriminator (test)   | 0.78 | 0.33            | 0.45
# Epoch 270 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 270:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.75 | 1.58            | 0.18
# generator (test)       | 1.54 | 1.33            | 0.21
# discriminator (train)  | 1.03 | 0.49            | 0.54
# discriminator (test)   | 0.71 | 0.19            | 0.52
# Epoch 271 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 271:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.74 | 1.56            | 0.18
# generator (test)       | 1.70 | 1.53            | 0.18
# discriminator (train)  | 1.02 | 0.50            | 0.53
# discriminator (test)   | 0.70 | 0.20            | 0.50
# Epoch 272 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 272:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.79 | 1.62            | 0.17
# generator (test)       | 1.63 | 1.45            | 0.18
# discriminator (train)  | 1.02 | 0.48            | 0.53
# discriminator (test)   | 0.68 | 0.21            | 0.47
# Epoch 273 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 273:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.85 | 1.68            | 0.17
# generator (test)       | 1.35 | 1.14            | 0.21
# discriminator (train)  | 0.99 | 0.46            | 0.53
# discriminator (test)   | 0.82 | 0.34            | 0.48
# Epoch 274 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 274:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.77 | 1.59            | 0.17
# generator (test)       | 1.39 | 1.16            | 0.23
# discriminator (train)  | 1.02 | 0.49            | 0.54
# discriminator (test)   | 0.73 | 0.27            | 0.46
# Epoch 275 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 275:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.75 | 1.58            | 0.17
# generator (test)       | 1.67 | 1.49            | 0.18
# discriminator (train)  | 1.02 | 0.49            | 0.53
# discriminator (test)   | 0.63 | 0.17            | 0.46
# Epoch 276 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 276:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.83 | 1.65            | 0.18
# generator (test)       | 1.48 | 1.27            | 0.21
# discriminator (train)  | 1.00 | 0.47            | 0.53
# discriminator (test)   | 0.70 | 0.24            | 0.46
# Epoch 277 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 277:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.76 | 1.58            | 0.18
# generator (test)       | 1.45 | 1.24            | 0.21
# discriminator (train)  | 1.04 | 0.49            | 0.55
# discriminator (test)   | 0.71 | 0.22            | 0.49
# Epoch 278 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 278:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.89 | 1.72            | 0.17
# generator (test)       | 1.54 | 1.30            | 0.25
# discriminator (train)  | 1.00 | 0.46            | 0.53
# discriminator (test)   | 0.66 | 0.17            | 0.49
# Epoch 279 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 279:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.75 | 1.57            | 0.18
# generator (test)       | 1.57 | 1.37            | 0.21
# discriminator (train)  | 1.03 | 0.49            | 0.54
# discriminator (test)   | 0.67 | 0.20            | 0.47
# Epoch 280 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 280:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.82 | 1.65            | 0.17
# generator (test)       | 1.08 | 0.77            | 0.31
# discriminator (train)  | 1.00 | 0.48            | 0.53
# discriminator (test)   | 0.97 | 0.37            | 0.60
# Epoch 281 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 281:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.80 | 1.63            | 0.17
# generator (test)       | 1.73 | 1.56            | 0.17
# discriminator (train)  | 1.02 | 0.49            | 0.53
# discriminator (test)   | 0.69 | 0.23            | 0.46
# Epoch 282 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 282:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.83 | 1.65            | 0.17
# generator (test)       | 1.38 | 1.16            | 0.22
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.75 | 0.24            | 0.51
# Epoch 283 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 283:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.78 | 1.61            | 0.17
# generator (test)       | 1.77 | 1.59            | 0.18
# discriminator (train)  | 1.01 | 0.48            | 0.53
# discriminator (test)   | 0.62 | 0.18            | 0.44
# Epoch 284 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 284:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.79 | 1.62            | 0.17
# generator (test)       | 1.77 | 1.61            | 0.16
# discriminator (train)  | 1.00 | 0.47            | 0.53
# discriminator (test)   | 0.68 | 0.24            | 0.44
# Epoch 285 of 2200
# 273/274 [============================>.] - ETA: 0s
# Testing for epoch 285:
# component              | loss | dense_loss      | dense_1_loss
# -----------------------------------------------------------------
# generator (train)      | 1.87 | 1.71            | 0.17
# generator (test)       | 2.40 | 2.27            | 0.13
# discriminator (train)  | 1.00 | 0.46            | 0.54
# discriminator (test)   | 0.64 | 0.22            | 0.42
# Epoch 286 of 2200
#  80/274 [=======>......................] - ETA: 1:03
